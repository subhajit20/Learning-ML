# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Titanic-Dataset.csv")

# %% [markdown]
# <h1>1. How big is the data?</h1>

# %%
df.shape # First parameter is number of rows. second param is number of columns
# Out:
# (891, 12)

# %% [markdown]
# <h1>2. How does the data look like?</h1>

# %%
# df.sample(5)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <h1>3. What is the data type of cols?</h1>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# <h1>4. Are there any missing values?</h1>

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# <h1>5. How does the data look mathematically?</h1>

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# <h1>6. Are there duplicate values?</h1>

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h1>7. How is the correlation between cols?</h1>

# %%
df.corr(numeric_only = True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# <h1>Univeriate Analysis for Numarical Data</h1>

# %% [markdown]
# <h2>a. Histogram</h2>

# %%
sns.histplot(data=df, x='Age', bins=80)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(data=df, x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
sns.displot(df["Age"],kde=True,legend=True)

# %% [markdown]
# <h1>Univeriate Analysis for Categorical Data</h1>

# %%
sns.countplot(x="Survived",data=df,legend=True)
plt.title('Univariate Analysis of Categorical Data')
plt.show()

# %%
df["Survived"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Survived'>

# %%
plt.pie(df["Survived"].value_counts(),labels=df["Survived"].value_counts(),autopct='%.1f')
# Out:
# ([<matplotlib.patches.Wedge at 0x133f5aa70>,
# ...
#  [Text(-0.39257493509945834, 1.0275626113924428, '549'),
#   Text(0.3925750313068116, -1.0275625746369201, '342')],
#  [Text(-0.2141317827815227, 0.5604886971231505, '61.6'),
#   Text(0.21413183525826085, -0.5604886770746836, '38.4')])

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# <h1>Biveriate Analysis</h1>

# %% [markdown]
# <h2>Biveriate Analysis between Categorical - Categorical column</h2>

# %%
pd.crosstab(index=df["Pclass"],columns=[df["Survived"],df["Sex"]])
# Out:
# Survived      0           1
# Sex      female male female male
# Pclass
# 1             3   77     91   45
# 2             6   91     70   17
# 3            72  300     72   47

# %%
sns.heatmap(pd.crosstab(df["Survived"],df["Sex"]))
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
sns.heatmap(pd.crosstab(df["Sex"],df["Survived"]))
# Out:
# <Axes: xlabel='Survived', ylabel='Sex'>

# %%
sns.heatmap(pd.crosstab(index=[df["Survived"],df["Sex"]],columns=df["Pclass"]))
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived-Sex'>

# %%
sns.heatmap(pd.crosstab(index=df["Survived"],columns=[df["Pclass"],df["Sex"],df["Embarked"]]))
# Out:
# <Axes: xlabel='Pclass-Sex-Embarked', ylabel='Survived'>

# %% [markdown]
# <h2>b.Biveriate Analysis between Numerical - Categorical column</h2>

# %%
sns.barplot(x=df["Pclass"],y=df["Age"],hue=df["Survived"])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(x=df["Sex"],y=df["Age"],hue=df["Survived"])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>
