# %% [markdown]
# <h1>Function Transformers</h1>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# <h1>Before Log Transformation</h1>

# %%
fig, axis = plt.subplots(nrows=1,ncols=2, figsize=(10, 5))

sns.histplot(df["fare"],kde=True,bins=10, label='data1', ax=axis[0])
stats.probplot(x=df["fare"],dist="norm",plot=plt)

plt.show()

# %%
import numpy as np

# %%
df["fare"] = np.log(df["fare"])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 357         0       2  female  38.0      0      0  2.564949        S  Second
# 458         1       2  female  50.0      0      0  2.351375        S  Second
# 652         0       3    male  21.0      0      0  2.132188        S   Third
# 562         0       2    male  28.0      0      0  2.602690        S  Second
# 622         1       3    male  20.0      1      1  2.756313        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# 357  woman       False  NaN  Southampton    no   True
# 458  woman       False  NaN  Southampton   yes   True
# 652    man        True  NaN  Southampton    no   True
# 562    man        True  NaN  Southampton    no   True
# 622    man        True  NaN    Cherbourg   yes  False

# %% [markdown]
# <h1>After Log Tranformation</h1>

# %%
fig, axis1 = plt.subplots(nrows=1,ncols=2, figsize=(10, 5))

sns.histplot(df["fare"],kde=True,bins=10, label='data1', ax=axis1[0])
stats.probplot(x=df["fare"],dist="norm",plot=plt)

plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/lib/function_base.py:2742: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
